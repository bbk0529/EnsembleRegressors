# %%
from regressors import *
import pickle
import pandas as pd

# %%
n_stations = 400
n_timesteps = 50
k = 5

# %%
ensembleregression = EnsembleRegression(n_regressors=5,n_variables=3, eps=4, decision_boundary=0.7)
ensembleregression2 = EnsembleRegression2(n_regressors=5,n_variables=3, eps=4, decision_boundary=0.7)
spatialcomparision = SpatialComparision()

# %%
data = Tempearture_DWD(n_stations, n_timesteps, k, p_noise=0.01)
# data = RandomData(n_stations,n_timesteps,k, p_noise = 0.01)
validator1 = Validator(data,ensembleregression)
validator2 = Validator(data,ensembleregression2)
validator3 = Validator(data,spatialcomparision)
# Out:
# [ 20 166 281 262]

# %%
d = (data.ts_data - data._ts_rawdata).flatten()
plt.hist(d[abs(d) >0])
# Out:
# (array([ 1.,  1.,  0.,  6.,  5.,  4., 10.,  7.,  3.,  3.]),
#  array([-36.79758247, -30.76452442, -24.73146636, -18.69840831,
#         -12.66535025,  -6.6322922 ,  -0.59923414,   5.43382391,
#          11.46688196,  17.49994002,  23.53299807]),
#  <BarContainer object of 10 artists>)

# %%
noise = data.ts_data - data._ts_rawdata
plt.figure(figsize=(10,10))
plt.imshow(noise)
plt.colorbar()

# %%
ts_data = data.ts_data

# %%
a = list(range(10))

# %%
stations_w_noises = set([int(x.split('_')[0]) for x in data.lst_station_timestep])

# %%
while True : 
    i = random.choice(range(len(ts_data)))
    if i not in stations_w_noises : 
        break
print(i)
iteration = 0
max_iteration = 10
while True  :
    candidate = list(range(len(ts_data)))
    candidate.remove(i)                                  
    idx = np.random.choice(candidate, size=3)
#     print(idx)
    X = ts_data[idx]
    y = ts_data[i]
    reg = LinearRegression().fit(X.T, y)
    score = reg.score(X.T,y)
    if score >= 0.9 : 
        print(i, score, idx)
        break
    
    iteration += 1
    print(idx, score, iteration)
    if iteration >= max_iteration : 
        print("cannot find more than .9")
        break
# Out:
# 390
# [150  20 392] 0.6904942009768169 1
# [ 37 357  63] 0.6683125483343946 1
# [357  84 397] 0.6436837631031922 1
# [ 39 311 387] 0.74690295499876 1
# [217  47 370] 0.7380923368083967 1
# [105 287 109] 0.5795978263149908 1
# [393 151 335] 0.6624017497662755 1
# [264  44 145] 0.6208461143518846 1
# [117 154 214] 0.6562613014057632 1
# [ 58  17 344] 0.7529404608343104 1
# [203 248 250] 0.6895189906396221 1
# [ 60 154  64] 0.5225034580177716 1
# [392  37 350] 0.5403438520323838 1
# [65 52 78] 0.6250905567247003 1
# [138 209 276] 0.5941463582451492 1
# [380 284 241] 0.6662439603699754 1
# [264 345  66] 0.6142755613198652 1
# [158 298 165] 0.8349574639068245 1
# [ 97 267 282] 0.6862673183502037 1
# [274 171 248] 0.7659951904703195 1
# [397 117  33] 0.798434896654679 1
# [211 363  31] 0.7006849211374975 1
# [109  86  37] 0.5759105763355057 1
# [320 399   5] 0.637174632800048 1
# [ 87 219  41] 0.3450754907564857 1
# [204 313 137] 0.6549344660884309 1
# [274 179  76] 0.8039482252440558 1
# [ 26 254 216] 0.7759884045718612 1
# [319  90  29] 0.6742520449317928 1
# [340 154 285] 0.6920887684451984 1
# [244  57   6] 0.6996902054428132 1
# [267 319 155] 0.7035457505361825 1
# [204 339 127] 0.7161856644261814 1
# [184 373 143] 0.758567873413426 1
# [318 130 223] 0.7786787878537023 1
# [293  47  46] 0.6969110315937717 1
# [  7 111 358] 0.6596857142031991 1
# [ 32 123 252] 0.5960003369079236 1
# [126 339 195] 0.5417316558521942 1
# [288 383 127] 0.7063757742411825 1
# [325 319 191] 0.7181972228867087 1
# [317 330   8] 0.7910323095539765 1
# [149 276 185] 0.7818921728262861 1
# [395 137 140] 0.7101504155239184 1
# [359 131 216] 0.7601074415910609 1
# [ 59 383 394] 0.6716309702907386 1
# [ 84 254 106] 0.8325641446681742 1
# [334 214  15] 0.701840563799174 1
# [272  62 397] 0.6968866239539556 1
# [109 258  39] 0.7077465242223402 1
# [329  96 323] 0.6492589018485311 1
# [256  84 106] 0.7583592297714514 1
# [ 74 256 317] 0.5417592074653101 1
# [ 98  14 205] 0.6056730882820552 1
# [337 150  64] 0.7214421470572179 1
# [204  45 311] 0.6828784970551007 1
# [182 266   4] 0.7696394008984636 1
# [232 261 325] 0.743905341150877 1
# [179 364 157] 0.7863960577662468 1
# [129 128  81] 0.40542945760003624 1
# [378 166 360] 0.618075323361201 1
# [319  84 381] 0.7353066709531946 1
# [384 285 295] 0.7082803633044661 1
# [357 103  28] 0.7052961240457127 1
# [383  39 324] 0.5928593171811016 1
# [147  97 273] 0.5667500792125855 1
# [ 25 380 311] 0.713013520249635 1
# [ 49  31 369] 0.7817797844833836 1
# [254 100 254] 0.7811087170703515 1
# [ 51 100 327] 0.7293479744055362 1
# [307 273 128] 0.6228285041925805 1
# [225  34 388] 0.7599431214817066 1
# [ 80 322 252] 0.41655213837463856 1
# [143 253 372] 0.7580734349072259 1
# [235 184 265] 0.7064608610302185 1
# [212 294 398] 0.6512808774585809 1
# [164  80 385] 0.5048915454723446 1
# [ 80 172 349] 0.4946362702227839 1
# [307  99  44] 0.6036784902932952 1
# [169 307 385] 0.6761406385154076 1
# [141 231 188] 0.6391481844681346 1
# [112 281  88] 0.643701713367838 1
# [225 377 289] 0.7549424352906775 1
# [182 192 168] 0.6182779433084107 1
# [362 325 259] 0.7883552919156795 1
# [184 347 384] 0.5616756270004547 1
# [209 284 166] 0.5849802866033433 1
# [171  67 398] 0.6667403078896119 1
# 390 0.9122123532357508 [202 316 309]

# %%
gap = reg.predict(X.T) - y 
mean = np.mean(gap)
sd = np.std(gap)
print(mean, sd)
plt.plot(reg.predict(X.T) - y )
# Out:
# -6.306066779870889e-16 0.1572254398088318

# %%
plt.plot(ts_data[i])
plt.plot(ts_data[idx].T, color='grey')
# Out:
# [<matplotlib.lines.Line2D at 0x7f1ba79f5250>,
#  <matplotlib.lines.Line2D at 0x7f1ba79f5340>,
#  <matplotlib.lines.Line2D at 0x7f1ba79f5400>]

# %%
data.lst_station_timestep
# Out:
# ['20_1',
#  '20_5',
#  '20_19',
#  '20_20',
#  '20_23',
#  '20_29',
#  '20_30',
#  '20_32',
#  '20_36',
#  '20_40',
#  '166_9',
#  '166_13',
#  '166_15',
#  '166_16',
#  '166_17',
#  '166_21',
#  '166_33',
#  '166_36',
#  '166_45',
#  '166_48',
#  '262_0',
#  '262_15',
#  '262_16',
#  '262_18',
#  '262_19',
#  '262_27',
#  '262_30',
#  '262_34',
#  '262_45',
#  '262_47',
#  '281_11',
#  '281_14',
#  '281_15',
#  '281_17',
#  '281_18',
#  '281_24',
#  '281_31',
#  '281_38',
#  '281_41',
#  '281_46']

# %%
validator1.evaluate_validator()
# Out:
# {'TP': 30,
#  'TN': 19960,
#  'FP': 0,
#  'FN': 10,
#  'n_stations': 400,
#  'n_timestep': 50,
#  'n_tsdata': 20000,
#  'p_noises': 0.002,
#  'precision': 1.0,
#  'recall': 0.75,
#  'f1': 0.8571428571428571}

# %%
validator2.evaluate_validator()
# Out:
# {'TP': 30,
#  'TN': 19957,
#  'FP': 3,
#  'FN': 10,
#  'n_stations': 400,
#  'n_timestep': 50,
#  'n_tsdata': 20000,
#  'p_noises': 0.002,
#  'precision': 0.9090909090909091,
#  'recall': 0.75,
#  'f1': 0.821917808219178}

# %%
validator3.evaluate_validator()
# Out:
# {'TP': 25,
#  'TN': 19286,
#  'FP': 674,
#  'FN': 15,
#  'n_stations': 400,
#  'n_timestep': 50,
#  'n_tsdata': 20000,
#  'p_noises': 0.002,
#  'precision': 0.0357653791130186,
#  'recall': 0.625,
#  'f1': 0.06765899864682004}

# %%
i = np.random.choice(list(set([int(i.split('_')[0]) for i in data.lst_station_timestep])))
plt.figure(figsize=(20,5))
plt.plot(data.ts_data[data._neighbor[i]].T, color='grey')
plt.plot(data.ts_data[i], color='red')
plt.title(i)
print([x for x in data.lst_station_timestep if x.startswith(str(i) + '_')])
print(validator1.validate(i))
print(validator2.validate(i))
print(validator3.validate(i))
# Out:
# ['1_0', '1_1', '1_3', '1_10', '1_11', '1_22', '1_33', '1_35', '1_43', '1_46']
# ['1_0', '1_1', '1_10', '1_11', '1_22', '1_33']
# ['1_0', '1_1', '1_10', '1_11', '1_22', '1_33']
# ['1_10', '1_22', '1_33', '1_35']

# %%
df_corr = pd.DataFrame(data.ts_data.T).corr()

# %%
idx_df_corr = df_corr.values.argsort()

# %%
data.lst_station_timestep
# Out:
# ['1_0',
#  '1_1',
#  '1_3',
#  '1_10',
#  '1_11',
#  '1_22',
#  '1_33',
#  '1_35',
#  '1_43',
#  '1_46',
#  '74_3',
#  '74_14',
#  '74_25',
#  '74_27',
#  '74_28',
#  '74_29',
#  '74_31',
#  '74_38',
#  '74_41',
#  '74_49',
#  '124_0',
#  '124_1',
#  '124_6',
#  '124_10',
#  '124_16',
#  '124_31',
#  '124_34',
#  '124_43',
#  '124_44',
#  '124_48',
#  '297_9',
#  '297_11',
#  '297_12',
#  '297_24',
#  '297_34',
#  '297_35',
#  '297_36',
#  '297_40',
#  '297_42',
#  '297_44']

# %%
i=297
df_corr.loc[i,idx_df_corr[i]]
# Out:
# 8     -0.176226
# 220   -0.163473
# 119   -0.147497
# 173   -0.141790
# 287   -0.138159
#          ...
# 181    0.166047
# 309    0.184320
# 259    0.225236
# 322    0.227759
# 297    1.000000
# Name: 297, Length: 400, dtype: float64

# %%
plt.plot(data.ts_data[297], color='red')
plt.plot(data.ts_data[[322,259,309, 181, 8, 220]].T, color='grey')
# Out:
# [<matplotlib.lines.Line2D at 0x7f50db7dbdc0>,
#  <matplotlib.lines.Line2D at 0x7f50db7dbeb0>,
#  <matplotlib.lines.Line2D at 0x7f50db7dbf70>,
#  <matplotlib.lines.Line2D at 0x7f50db7e8070>,
#  <matplotlib.lines.Line2D at 0x7f50db7e8130>,
#  <matplotlib.lines.Line2D at 0x7f50db7e81f0>]

# %%
gap = data.ts_data - data._ts_rawdata

# %%
plt.plot(gap[297])

# %%
# X = data.ts_data[[322,259,309]]
X = data.ts_data[[322,259,309, 181, 181, 8, 220]] 
y = data.ts_data[297]
reg = LinearRegression().fit(X.T, y)
print(reg.score(X.T,y))
predict = reg.predict(X.T)
plt.plot(predict , color='grey')
plt.plot(y, color='red')
plt.figure()
plt.plot((predict - y)>2 )
# Out:
# 0.2384701452675464

# %%
plt.plot(data.ts_data[297])
plt.plot(data.ts_data[[8,220]].T, color='grey')
# Out:
# [<matplotlib.lines.Line2D at 0x7f50db8769a0>,
#  <matplotlib.lines.Line2D at 0x7f50db876bb0>]

# %%
X = data.ts_data[[293,23]]
y = data.ts_data[0]
reg = LinearRegression().fit(X.T, y)
print("R^2:", reg.score(X.T, y))
print("SquaredSum:", sum((reg.predict(X.T) - y)**2))
# Out:
# R^2: 0.9341928935149021
# SquaredSum: 1.1880683390606603

# %%
X = data.ts_data[[313,147]]
y = data.ts_data[0]
reg = LinearRegression().fit(X.T, y)
print("R^2:", reg.score(X.T, y))
print("SquaredSum:", sum((reg.predict(X.T) - y)**2))
# Out:
# R^2: 0.9135066059158353
# SquaredSum: 1.561534438116693

# %%
IDX.shape
# Out:
# (10, 400)

# %%
df_corr.loc[74, IDX[]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-117-9a5c7d4ef7b9> in <module>
# ----> 1 df_corr.loc[74, IDX[74]]
#
# IndexError: index 74 is out of bounds for axis 0 with size 10

# %%
data.lst_station_timestep
# Out:
# ['1_0',
#  '1_1',
#  '1_3',
#  '1_10',
#  '1_11',
#  '1_22',
#  '1_33',
#  '1_35',
#  '1_43',
#  '1_46',
#  '74_3',
#  '74_14',
#  '74_25',
#  '74_27',
#  '74_28',
#  '74_29',
#  '74_31',
#  '74_38',
#  '74_41',
#  '74_49',
#  '124_0',
#  '124_1',
#  '124_6',
#  '124_10',
#  '124_16',
#  '124_31',
#  '124_34',
#  '124_43',
#  '124_44',
#  '124_48',
#  '297_9',
#  '297_11',
#  '297_12',
#  '297_24',
#  '297_34',
#  '297_35',
#  '297_36',
#  '297_40',
#  '297_42',
#  '297_44']

# %%
validator1.spatial_reference(data._metadata[0], data._metadata[313])['distance']/1000
# Out:
# 461.92596225727857

# %%
reg.score(X.T, y)
sum((reg.predict(X.T) - y)**2)
# Out:
# 0.9341928935149021

# %%
plt.plot(data.ts_data[0])
plt.plot(data.ts_data[[293,23]].T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f50dc2d3820>,
#  <matplotlib.lines.Line2D at 0x7f50dc2d3910>]

# %%
IDX = abs(pd.DataFrame(data.ts_data.T).corr().values).argsort()[-10:]

# %%
data.ts_data[IDX[0]]
# Out:
# array([[-0.4, -0.4, -0.5, ..., -0.5, -0.6, -0.7],
#        [ 1.9,  2. ,  2. , ...,  1.1,  1.1,  1. ],
#        [ 0.7,  0.9,  0.8, ...,  0.9,  1. ,  1.1],
#        ...,
#        [-0.6, -0.8, -0.9, ..., -3.1, -3.1, -2.8],
#        [ 1.6,  1.6,  1.4, ..., -1.3, -1.5, -1.1],
#        [ 0.6, -0.2, -0.4, ..., -2.1, -2.2, -2.1]])

# %%
plt.plot(np.dot(PRED.T, SCORE) - ts_data[i])

# %%
SCORE[7]

# %%
idx_variables

# %%
ts_data[neighbor[i]][idx_variables]

# %%
plt.plot(ts_data[0])
plt.plot(ts_data[neighbor[0]].T, color='grey')

# %%
data = data.ts_data
neighbor = data._neighbor

# %%
plt.figure(figsize=(20,5))
plt.plot(data[0], color='red')
plt.plot(data[neighbor[0]].T, color='grey')

# %%
data[0]

# %%
pd.concat([pd.DataFrame(data[0]), pd.DataFrame(data[neighbor[0]]).T], axis=1).corr()

# %%
data._lst

# %%
import random
idx = random.choices(neighbor[0], k=3)
X = data[idx]
y = data[0]

# %%
reg = LinearRegression().fit(X.T, y)

# %%
reg.score(X.T, y)

# %%
plt.plot(reg.predict(X.T))
plt.plot(y)
# plt.plot(reg.predict(X.T) - y)

# %%
pd.DataFrame(data[neighbor[0]]).corr()

# %%
data.tsneighbor[0]

# %%
import time
RESULT = [] 
for n_timesteps in range(1000, 10000, 1000) : 
    print(n_stations, n_timesteps)
    ensembleregression = EnsembleRegression(n_regressors=5,n_variables=3,eps=4, decision_boundary=0.7)    
    data = Tempearture_DWD(n_stations, n_timesteps, k, p_noise=0.01)
    # data = RandomData(20,20,5, p_noise = 0.01)
    validator1 = Validator(data,ensembleregression)
    validator2 = Validator(data,spatialcomparision)
    start = time.time()
    validator1.evaluate_validator()
    end = time.time() - start
    
    print(end)
    RESULT.append(end)

# %%
import time
RESULT2 = [] 
for n_timesteps in range(1000, 10000, 1000) : 
    ensembleregression = EnsembleRegression(n_regressors=5,n_variables=3,eps=4, decision_boundary=0.7)
    spatialcomparision = SpatialComparision()
    data = Tempearture_DWD(n_stations, n_timesteps, k, p_noise=0.1)
    # data = RandomData(20,20,5, p_noise = 0.01)
    validator1 = Validator(data,ensembleregression)
    validator2 = Validator(data,spatialcomparision)
    start = time.time()
    validator1.evaluate_validator()
    RESULT2.append(time.time() - start)

# %%
plt.figure(figsize=(20,10))
plt.plot(RESULT)
plt.plot(RESULT2)
plt.legend(['new','old'])

# %%
plt.figure(figsize=(5,5))
plt.imshow(data.ts_data)

# %%
validator1.evaluate_validator()

# %%
validator2.evaluate_validator()

# %%
# %%timeit
validator1.evaluate_validator()

# %%
# %%timeit
validator1.evaluate_validator()

# %%
# %%timeit
validator1.evaluate_validator()

# %%
# %%timeit
validator2.evaluate_validator()

# %%
# %%timeit
validator2.evaluate_validator()

# %%
# %%timeit
validator2.evaluate_validator()

# %%
s = int(random.choice(data.lst_station_timestep).split('_')[0])

plt.figure(figsize=(20,5))
plt.plot(data.ts_data[s], color='red')
plt.plot(data.ts_data[data._neighbor[s]].T, color='grey')
plt.title(s)
print("answer", [x for x in data.lst_station_timestep if x.startswith(str(s) + '_')])
print("new_idea", validator1.validate(s))
print("exsiting_idea", validator2.validate(s))

# %%
plt.scatter(data._metadata[:,1], data._metadata[:,2], color='grey')
plt.scatter(data._metadata[s,1], data._metadata[s,2], color='red')
plt.scatter(data._metadata[data._neighbor[s]][:,1], data._metadata[data._neighbor[s]][:,2], color='blue')

# %%
for d in data._metadata[data._neighbor[s]] : 
    
    print(validator1.spatial_reference(data._metadata[s], d)['distance'])

# %%
d = data._metadata[:,1:]

# %%
distance_matrix(d,d)[0]

# %%
distance_matrix(d,d)[0][distance_matrix(d,d)[0].argsort()]

# %%
data._metadata[data._neighbor[s]]

# %%
df = pickle.load(open('data_dvd_reduced.p','rb'))
df_metadata = pickle.load(open('metadata.p', 'rb'))
metadata = df_metadata.values[:400]
neighbor = create_neighor_list(metadata[:,1:], k=5)
ts_rawdata = df.values[:400]
ts_preprocessed_data = preprocess_data(ts_rawdata)[:,5000:7000]

# %%
ts_data, ANSWER, lst_noises = add_noise(ts_preprocessed_data, 0.10, 3, 10)

# %%
plt.figure(figsize=(10,10))
plt.imshow(ts_data)

# %%
eps=4
n_regressors = 5
n_variables = 3

# %%
RESULT = []
for i in range(100) : 
    result = evaluator(ts_data, ANSWER, neighbor, classifier = regression_based_outlier_detection, n_regressors=n_regressors, n_variables=n_variables, eps=eps)['f1']
    RESULT.append(result)
print(np.mean(RESULT))

# %%
RESULT = []
for i in range(100) : 
    result = evaluator(ts_data, ANSWER, neighbor, classifier = regression_based_outlier_detection2, n_regressors=n_regressors, n_variables=n_variables, eps=eps)['f1']
    RESULT.append(result)
print(np.mean(RESULT))

# %%
RESULT = []
for i in range(100) : 
    result = evaluator(ts_data, ANSWER, neighbor, classifier = regression_based_outlier_detection3, n_regressors=n_regressors, n_variables=n_variables, eps=eps)['f1']
    RESULT.append(result)
print(np.mean(RESULT))

# %%
# %%timeit
evaluator(ts_data, ANSWER, neighbor, classifier = spatialcomparision, n_regressors=n_regressors, n_variables=n_variables, eps=eps)['f1']

# %%
# %%timeit
evaluator(ts_data, ANSWER, neighbor, classifier = regression_based_outlier_detection, n_regressors=n_regressors, n_variables=n_variables, eps=eps)['f1']

# %%
# %%timeit
evaluator(ts_data, ANSWER, neighbor, classifier = regression_based_outlier_detection2, n_regressors=n_regressors, n_variables=n_variables, eps=eps)['f1']

# %%
# %%timeit
evaluator(ts_data, ANSWER, neighbor, classifier = regression_based_outlier_detection3, n_regressors=n_regressors, n_variables=n_variables, eps=eps)['f1']

# %%
STAT = evaluator(ts_data, ANSWER, neighbor, classifier = spatialcomparision)
STAT

# %%
s = random.choice(list(set([k[0] for k,v in lst_noises.items()])))

plt.figure(figsize=(20,5))
plt.plot(ts_data[s], color='red')
plt.plot(ts_data[neighbor[s]].T , color='grey')
plt.title(s)

d = [(k,v) for k,v in sorted(lst_noises.items(), reverse=False, key=lambda x : x[0][0]) if k[0] == s]
print([(k,v) for k,v in sorted(d, reverse=False, key=lambda x : x[0][1])])
result1 = regression_based_outlier_detection(ts_data, neighbor, s, n_regressors, n_variables, eps=eps)
result2 = regression_based_outlier_detection2(ts_data, neighbor, s, n_regressors, n_variables, eps=eps)
result3 = regression_based_outlier_detection2(ts_data, neighbor, s, n_regressors, n_variables, eps=eps)
result4 = spatialcomparision(ts_data, neighbor, s)

print("classified by new idea", result1)
# print("classified by new idea2", result2)
# print("classified by new idea3", result3)
print("classified by old idea", result4)

# %%
# %%timeit
spatialcomparision(ts_data, neighbor, station=s)

# %%
# %%timeit
regression_based_outlier_detection(ts_data, neighbor, s, n_regressors=n_regressors, n_variables=n_variables, eps=3)

# %%
n_regressors = 7
result = np.empty(len(ts_data[s]))
for i in range(n_regressors) : 
    idx = random.choices(neighbor[s],k=2)
    X = ts_data[idx]
    y = ts_data[s]
    reg = LinearRegression().fit(X.T, y)
    predict = reg.intercept_ + np.dot(X.T, reg.coef_)
    result += predict    
    print(idx, reg.score(X.T, y))
result = result / n_regressors

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(30,10))
ax1 = plt.subplot(131)
ax2 = plt.subplot(132)
ax3 = plt.subplot(133)

ax1.plot(ts_data[s], color='red')
ax1.plot(ts_data[neighbor[s]].T, color='grey')

ax2.plot(y, color='red')
ax2.plot(result, color='grey')


# ylim = [-1000,40]
# ax1.set_ylim(ylim)
# ax2.set_ylim(ylim)

diff = predict-y

ax3.plot(diff, color='red')

# %%
def regression_based_outlier_detection2(ts_data, neighbor, station, n_regressors, n_variables, eps) :
    result = np.array([], dtype='int')
    coeffs = np.zeros((n_regressors, n_variables + 1))
    score = np.zeros(n_regressors)
    predict = np.zeros((n_regressors, ts_data.shape[1]))
    for i in range(n_regressors) : 
        idx = random.choices(neighbor[station],k=n_variables)
        y = ts_data[station] 
        X = ts_data[idx]
        reg = LinearRegression().fit(X.T, y)
        score[i] = reg.score(X.T, y)
        predict[i] = reg.intercept_ + np.dot(X.T, reg.coef_)
        
    
    print(score)
    idx = (-score).argsort()[:-1]
    score = score / score.sum()    
    return np.dot(predict[idx].T, score[idx])

# %%
regression_based_outlier_detection2(ts_data, neighbor, s, n_regressors=10, n_variables=3, eps=2)

# %%
predict

# %%
score.sum()

# %%
np.dot(predict.T, score)

# %% [markdown]
# # random test

# %%
n_variables = 3
idx = random.choices(neighbor[s],k=n_variables)
print(idx)
y = ts_data[s]
X = ts_data[neighbor[s]]
reg = LinearRegression().fit(X.T, y)
predict = reg.intercept_ + np.dot(X.T, reg.coef_)
score = reg.score(X.T,y)
print(score)

# %%
original = ts_rawdata[s]
predict = reg.intercept_ + np.dot(X.T, reg.coef_)
plt.plot(original)
plt.plot(predict)
plt.plot(original-predict)

# %%
mean = np.mean(diff)
sd = np.std(diff)
result_stat = np.where((diff >= mean + 2* sd)  | (diff  <= mean - 2* sd ))[0]

# %%
ANSWER.sort()
ANSWER

# %%
result_stat
