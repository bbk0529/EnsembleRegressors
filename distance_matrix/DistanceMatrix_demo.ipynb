# %%
from scalable_dist_matrix_ import DistanceMatrix

# %%
dm = DistanceMatrix(N=10000, s=100, p=1)

# %%
dm._data
# Out:
# array([[0.94352323, 0.37726727],
#        [0.89636063, 0.88482558],
#        [0.20874059, 0.57926234],
#        ...,
#        [0.09885204, 0.5792511 ],
#        [0.93398488, 0.52137982],
#        [0.1024894 , 0.1487429 ]])

# %%
dm._data.shape
# Out:
# (10000, 2)

# %%
dm.create_dist_matrix()
dm.find_neighbor()

# %%
dm._DIST[0,0]
# Out:
# array([[0.        , 0.00284618, 0.01661906, 0.01329864, 0.00424226,
#         0.01028605, 0.01271667],
#        [0.00284618, 0.        , 0.01744722, 0.01110827, 0.00708329,
#         0.0112339 , 0.01068467],
#        [0.01661906, 0.01744722, 0.        , 0.01667647, 0.01658354,
#         0.00633311, 0.01558442],
#        [0.01329864, 0.01110827, 0.01667647, 0.        , 0.01707144,
#         0.01318023, 0.00110981],
#        [0.00424226, 0.00708329, 0.01658354, 0.01707144, 0.        ,
#         0.01059049, 0.01636377],
#        [0.01028605, 0.0112339 , 0.00633311, 0.01318023, 0.01059049,
#         0.        , 0.01209108],
#        [0.01271667, 0.01068467, 0.01558442, 0.00110981, 0.01636377,
#         0.01209108, 0.        ]])

# %%
dm.NEIGHBOR

# %%
dm.pick_and_draw_random_block()

# %%
dm = DistanceMatrix(N=10000, s=100, p=0.5)
dm.create_dist_matrix()
dm.find_neighbor()
dm.pick_and_draw_random_block()

# %%
dm = DistanceMatrix(N=10000, s=10, p=0.5)
dm.create_dist_matrix()
dm.find_neighbor()
dm.pick_and_draw_random_block()

# %%
dm = DistanceMatrix(N=10000, s=10, p=2)
dm.create_dist_matrix()
dm.find_neighbor()
dm.pick_and_draw_random_block()

# %%
import matplotlib.pyplot as plt
plt.figure()

# %%
plt.xlim([10,10])
plt.xlim(10,10)

# %%
dm = DistanceMatrix(N=10000, s=10, p=0.1)
dm.create_dist_matrix()
dm.find_neighbor()
dm.pick_and_draw_random_block()

# %%
dm = DistanceMatrix(N=10000, s=10, p=2)
dm.create_dist_matrix()
dm.find_neighbor()
dm.pick_and_draw_random_block()
