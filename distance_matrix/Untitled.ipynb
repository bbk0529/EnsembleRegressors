# %%
import numpy as np
import pandas as pd

# %%
col = [
    'N',
    'slicing',
    'padding',
    'runtime',
    'matrixsize',
    'reducedsize',
    'factor'
    
]
df = pd.read_csv('test_result.txt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-518f88ea5f84> in <module>
#       9
#      10 ]
# ---> 11 df = pd.read_csv('test_result.txt', usecols = col)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
df = pd.read_csv('test_result.txt')

# %%
df.columns = col

# %%
df.groupby('N').min()
# Out:
#         slicing  padding  runtime   matrixsize  reducedsize  factor
# N
# 3200         10      0.5   0.0450     10240000        13758    0.25
# 6400         10      0.5   0.0877     40960000        29486    0.25
# 12800        10      0.5   0.2309    163840000        68184    0.25
# 25600        10      0.5   0.4570    655360000       166890    1.17
# 50000        25      0.5   1.2412   2500000000       448374    2.81
# 100000       50      0.5   4.1340  10000000000      1395292   10.43
# 200000       50      0.5   8.4262  40000000000      4787307   40.16
# 300000       50      0.5  16.4569  90000000000     10156931  125.65

# %%
for i in [3200, 6400, 12800, 25600, 50000, 100000, 200000, 300000] : 
    print(df[df['runtime'] == df.groupby('N').min()['runtime'][i]])
# Out:
#       N  slicing  padding  runtime  matrixsize  reducedsize  factor
# 4  3200       25      0.5    0.045    10240000       257736   39.73
#        N  slicing  padding  runtime  matrixsize  reducedsize  factor
# 28  6400       25      0.5   0.0877    40960000       994243    41.2
#         N  slicing  padding  runtime  matrixsize  reducedsize  factor
# 56  12800       50      0.5   0.2309   163840000      1061206  154.39
#         N  slicing  padding  runtime  matrixsize  reducedsize  factor
# 78  25600       50      0.5    0.457   655360000      4154035  157.76
#          N  slicing  padding  runtime  matrixsize  reducedsize  factor
# 100  50000       50      0.5   1.2412  2500000000     15610154  160.15
#           N  slicing  padding  runtime   matrixsize  reducedsize  factor
# 116  100000       50      0.5    4.134  10000000000     62252706  160.64
#           N  slicing  padding  runtime   matrixsize  reducedsize  factor
# ...

# %%
df.groupby('N').min()['runtime'][3200]
# Out:
# 0.045

# %%
data = df[df['N'] == 200000]

# %%
# Out:
#           N  slicing  padding   runtime   matrixsize  reducedsize   factor
# 0      3200       10      0.5    0.0849     10240000      1367108     7.49
# 1      3200       10      1.0    0.4165     10240000      6568042     1.56
# 2      3200       10      1.5    1.1915     10240000     18368057     0.56
# 3      3200       10      2.0    3.1895     10240000     41625665     0.25
# 4      3200       25      0.5    0.0450     10240000       257736    39.73
# ..      ...      ...      ...       ...          ...          ...      ...
# 148  300000      400      0.5  121.0180  90000000000     10156931  8860.94
# 149  300000      400      1.0  125.2422  90000000000     48011628  1874.55
# 150  300000      400      1.5  130.6958  90000000000    147683658   609.41
# 151  300000      400      2.0  142.0394  90000000000    355434412   253.21
# 152  300000       50      0.5   39.5903  90000000000    556914846   161.60
#
# [153 rows x 7 columns]
